# %% [markdown]
# # Vetores e Álgebra Linear no Espaço Vetorial

# %% [markdown]
# ## Axiomas de Operações com Vetores no Espaço Vetorial
#
# Um espaço vetorial, como o próprio nome indica, é o espaço para vetores, que define duas operações, **adição** e **multiplicação por escalares**, sujeitas aos axiomas abaixo:

# %% [markdown]
# 1. A soma de ${u}$ e ${v}$, indicado por ${u}+{v},$ está em $V$
# 2. ${u}+{v}={v}+{u}$
# 3. $({u}+{v})+{w}={u}+({v}+{w})$
# 4. Existe um vetor nulo $0$ em $V$ tal que ${u}+{0}={u}$
# 5. Para cada ${u}$ em $V$, há um vetor $-{u}$ in $V$ tal que ${u}+(-{u})={0}$
# 6. A multipplicação do escalar ${u}$ por $c,$ indicado por $c {u},$ está em $V$
# 7. $c({u}+{v})=c {u}+c {v}$
# 8. $(c+d) {u}=c {u}+d {u}$
# 9. $c(d {u})=(c d) {u}$
# 10. $1 {u}={u}$

# %% [markdown]
# # Subespaço em Álgebra Linear
#
# Um subespaço é um dos conceitos mais importantes em álgebra linear, felizmente nada realmente misterioso.
#
# Um subespaço reside em um espaço vetorial $V$, podemos denotar como $H$. Apenas duas propriedades precisam ser verificadas:
#
# 1. $H$ tem vetor zero.
# 2. Podemos realizar adição vetorial e multiplicação escalar.
#
# Existem dois fatos sobre os subespaços:
#
# 1. Qualquer linha que passa $(0, 0)$ em $\mathbb{R}^2$ é um subespaço de $\mathbb{R}^2$.
# 2. Qualquer plano que passa $(0, 0, 0)$ em $\mathbb{R}^3$ é um subespaço de $\mathbb{R}^3$.
#
# A seguir vamos visualizar o subespaço.

# %% [markdown]
# ## O Que é Subespaço Vetorial?

# %% [markdown]
# Um **subespaço vetorial** é um conceito fundamental da **Álgebra Linear**. Trata-se de um **conjunto de vetores** dentro de um espaço vetorial maior que satisfaz algumas propriedades específicas. Para que um conjunto seja considerado um subespaço vetorial, ele deve atender às **três condições abaixo**:
#
# ### 1. Fechamento sob Adição
# Se você pegar **dois vetores** quaisquer dentro do subespaço e **soma-los**, o vetor resultante **também deve pertencer** ao subespaço.
#
# > Formalmente:
# Se **𝑢** e **𝑣** pertencem ao subespaço, então **𝑢 + 𝑣** também pertence.
#
# ### 2. Fechamento sob Multiplicação Escalar
# Se você pegar um vetor do subespaço e **multiplicá-lo por um escalar** (número real ou complexo), o vetor resultante **deve continuar no subespaço**.
#
# > Formalmente:
# Se **𝑣** pertence ao subespaço e **𝑐** é um escalar, então **𝑐𝑣** também pertence.
#
# ### 3. Contém o Vetor Nulo
# Todo subespaço vetorial **deve conter o vetor nulo** (ou seja, o vetor com todas as componentes iguais a zero).
#
# > Isso ocorre porque:
# - Adicionar o vetor nulo a qualquer vetor não altera o vetor.
# - Multiplicar qualquer vetor pelo escalar zero resulta no vetor nulo.
#
#
# ### Exemplo em ℝ³ (espaço tridimensional)
# Considere o espaço vetorial ℝ³ (todos os vetores tridimensionais com entradas reais):
#
# - Uma **linha** que **passa pela origem** é um subespaço vetorial.
# - Um **plano** que **passa pela origem** também é um subespaço vetorial.
#
# No entanto:
# - Uma linha ou plano que **não passa pela origem** **não** é subespaço, pois **não contém o vetor nulo**.
#
#
# ### Importância
# Subespaços vetoriais ajudam a:
# - Compreender a **estrutura interna** de um espaço vetorial.
# - **Decompor** espaços em partes menores e mais manejáveis.
# - Estudar **transformações lineares** e **soluções de sistemas lineares** com mais clareza.

# %% [markdown]
# ### Aplicação do Conceito de Subespaço Vetorial em Data Science e Machine Learning
#
# O conceito de subespaço vetorial é fundamental em Data Science e Machine Learning, desempenhando um papel importante em várias técnicas e algoritmos. Abaixo estão algumas de suas principais aplicações:
#
# **Redução de Dimensionalidade:**
#
# Em Data Science, frequentemente lidamos com conjuntos de dados de alta dimensionalidade. Técnicas como **Análise de Componentes Principais (PCA)** e **Singular Value Decomposition (SVD)** são usadas para reduzir essa dimensionalidade. Elas projetam os dados em subespaços vetoriais de menor dimensão, mantendo a maior parte da variância dos dados originais. Isso é útil para:
#         - Visualização,
#         - Compressão de dados,
#         - Melhoria no desempenho de algoritmos de aprendizado de máquina.
#
# **Espaços de Recursos:**
#
# Em aprendizado de máquina, os dados são representados como vetores em um **espaço de recursos**, onde cada dimensão corresponde a uma característica dos dados. Subespaços vetoriais podem representar:
# - Combinações de características,
# - Transformações que revelam estruturas úteis para resolver o problema de interesse.
#
# **Regularização:**
#
# Métodos como **Lasso** e **Ridge** aplicam regularização para evitar o sobreajuste. Esses métodos podem ser interpretados como formas de restringir a solução a um subespaço vetorial, controlando a complexidade do modelo.
#
# **Clustering e Classificação:**
#
# Algoritmos como **K-means** e **Support Vector Machines (SVM)** operam em espaços vetoriais. No caso do SVM, por exemplo, um **hiperplano** (subespaço vetorial) é utilizado para separar as classes. A escolha apropriada desse hiperplano impacta diretamente o desempenho do classificador.
#
# **Processamento de Linguagem Natural (PLN):**
#
# Técnicas como **análise semântica latente (LSA)** usam subespaços vetoriais para representar significados de palavras e documentos. Essa projeção permite capturar:
# - Relações semânticas,
# - Padrões sintáticos relevantes em grandes volumes de texto.
#
# **Análise de Séries Temporais**
#
# Na modelagem de séries temporais, subespaços vetoriais ajudam a identificar:
# - Tendências,
# - Componentes principais,
# - Padrões de comportamento ao longo do tempo, facilitando previsões e análises mais robustas.
#
# **Redes Neurais**
#
# Cada camada de uma **rede neural profunda** pode ser vista como uma transformação de um espaço vetorial para outro. A aprendizagem consiste em encontrar subespaços que melhor representem os dados, tornando a rede capaz de extrair características relevantes para a tarefa final.
#
#
# > O conceito de subespaço vetorial é uma ferramenta matemática essencial para simplificar e interpretar dados complexos e de alta dimensão. Ele é a base para diversas abordagens de modelagem, análise e tomada de decisão em Data Science e Machine Learning.

# %% [markdown]
# ## Visualização do Subespaço vetorial
#
# ### em $\mathbb{R}^2$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Cria a figura
fig, ax = plt.subplots(figsize = (8, 8))

# Valores de x e y
x = np.arange(-10, 11, 1)
y = 4/6*x

# Plot
ax.plot(x, y, lw = 4, color = 'green', label = r'$y = \frac{2}{3}x$, subespaço de $\mathbf{R}^2$')

# Novo valor de y
y = -3+4/6*x

# Plot
ax.plot(x, y, lw = 4, color = 'red', label = r'$y = -3+\frac{2}{3}x$, não é um subespaço de $\mathbf{R}^2$')

# Grid
ax.grid(True)

# Título
ax.set_title('Visualização de Subespaço em $R^2$ ', size = 18)

# Scatter Plot
ax.scatter(0, 0, s = 100, fc = 'black', ec = 'red')

# Texto e legenda
ax.text(-2, 0, '$(0,0)$', size = 18)
ax.legend(fontsize = 16)

# Coordenadas dos eixos
ax.axis([-10, 10, -10, 10])

# Labels
ax.set_xlabel('Eixo X', size = 18)
ax.set_ylabel('Eixo Y', size = 18)

# Plot
plt.show()

# %% [markdown]
# ### Visualização do Subespaço vetorial em $\mathbb{R}^3$
#
# Considere um intervalo de dois vetores $u = (1,-2,1)^S$ e $v=(2,1,2)^T$. O intervalo de $(u,v)$ é um subespaço de $\mathbb{R}^3$, onde $s$ e $t$ são os escalares dos vetores.
#
# $$
# \left[
# \begin{matrix}
# x\\
# y\\
# z
# \end{matrix}
# \right]=
# s\left[
# \begin{matrix}
# 1\\
# -2\\
# 1
# \end{matrix}
# \right]+
# t\left[
# \begin{matrix}
# 2\\
# 1\\
# 2
# \end{matrix}
# \right]=
# \left[
# \begin{matrix}
# s+2t\\
# -2s+t\\
# s+2t
# \end{matrix}
# \right]
# $$
#
# Vamos também definir um plano que não é um subespaço adicionando $2$ na terceira equação, ou seja, $z= s+2t+2$.
#
# E então criamos o plot.

# %%
# Cria a figura
fig = plt.figure(figsize = (8, 8))

# Projeção 3D
ax = fig.add_subplot(111, projection = '3d')

# Valores de s e t
s = np.linspace(-1, 1, 10)
t = np.linspace(-1, 1, 10)

# Grid
S, T = np.meshgrid(s, t)

# Valores de x, y e z
X = S + 2 * T
Y = -2 * S + T
Z = S + 2 * T

# Plot
ax.plot_surface(X, Y, Z, alpha = .9, cmap = plt.cm.coolwarm)

# Isso não é mais um subespaço
Z2 = S + 2 * T + 2 

# Plot
ax.plot_surface(X, Y, Z2, alpha = .6, cmap = plt.cm.jet)

# Scatter
ax.scatter(0,0,0, s = 200, color = 'red')

# Texto
ax.text(0, 0, 0, '$(0,0,0)$', size = 18, zorder = 5)

# Título
ax.set_title('Visualização de Subespaço em $\mathbb{R}^3$', x = .5, y = 1.1, size = 20)

# Labels
ax.set_xlabel('Eixo x', size = 18)
ax.set_ylabel('Eixo y', size = 18)
ax.set_zlabel('Eixo z', size = 18)
plt.show()
